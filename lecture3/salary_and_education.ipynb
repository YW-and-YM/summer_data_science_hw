# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_path = "/Users/yuema/MyCode/summer_data_science_hw/lecture3/Salary.csv"
salary_data = pd.read_csv(data_path)

# %%
salary_data
# Out:
#        Age  Gender  Education Level              Job Title  \
# 0     32.0    Male                1      Software Engineer
# 1     28.0  Female                2           Data Analyst
# 2     45.0    Male                3                Manager
# 3     36.0  Female                1        Sales Associate
# 4     52.0    Male                2               Director
# ...    ...     ...              ...                    ...
# 6679  49.0  Female                3  Director of Marketing
# 6680  32.0    Male                0        Sales Associate
# 6681  30.0  Female                1      Financial Manager
# 6682  46.0    Male                2      Marketing Manager
# 6683  26.0  Female                0        Sales Executive
#
#       Years of Experience    Salary    Country        Race  Senior
# 0                     5.0   90000.0         UK       White       0
# 1                     3.0   65000.0        USA    Hispanic       0
# ...

# %%
salary_threshold = np.median(salary_data["Salary"])

# %%
salary_data["Salary"]
# Out:
# 0        90000.0
# 1        65000.0
# 2       150000.0
# 3        60000.0
# 4       200000.0
#           ...
# 6679    200000.0
# 6680     50000.0
# 6681     55000.0
# 6682    140000.0
# 6683     35000.0
# Name: Salary, Length: 6684, dtype: float64

# %%
salary_threshold
# Out:
# np.float64(115000.0)

# %%
salary_level_list = []
for i in range(len(salary_data)):
    if salary_data.iloc[i]["Salary"] < salary_threshold:
        salary_level_list.append("Low")
    else:
        salary_level_list.append("High")

# %%
salary_data["salary_level"] = np.array(salary_level_list)

# %%
salary_data
# Out:
#        Age  Gender  Education Level              Job Title  \
# 0     32.0    Male                1      Software Engineer
# 1     28.0  Female                2           Data Analyst
# 2     45.0    Male                3                Manager
# 3     36.0  Female                1        Sales Associate
# 4     52.0    Male                2               Director
# ...    ...     ...              ...                    ...
# 6679  49.0  Female                3  Director of Marketing
# 6680  32.0    Male                0        Sales Associate
# 6681  30.0  Female                1      Financial Manager
# 6682  46.0    Male                2      Marketing Manager
# 6683  26.0  Female                0        Sales Executive
#
#       Years of Experience    Salary    Country        Race  Senior  \
# 0                     5.0   90000.0         UK       White       0
# 1                     3.0   65000.0        USA    Hispanic       0
# ...

# %%
mask_level_0 = salary_data["Education Level"] == 0
people_level_0 = salary_data[mask_level_0]

# %%
mask_level_0
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6679    False
# 6680     True
# 6681    False
# 6682    False
# 6683     True
# Name: Education Level, Length: 6684, dtype: bool

# %%
people_level_0
# Out:
#        Age  Gender  Education Level                  Job Title  \
# 2390  30.0    Male                0           Project Engineer
# 2398  28.0    Male                0         Back end Developer
# 2405  24.0  Female                0           Project Engineer
# 2414  43.0    Male                0          Software Engineer
# 2423  49.0  Female                0           Project Engineer
# ...    ...     ...              ...                        ...
# 6666  32.0    Male                0       Sales Representative
# 6669  26.0  Female                0            Sales Associate
# 6674  27.0    Male                0  Digital Marketing Manager
# 6680  32.0    Male                0            Sales Associate
# 6683  26.0  Female                0            Sales Executive
#
#       Years of Experience    Salary    Country        Race  Senior  \
# 2390                 11.0  103947.0  Australia       Asian       1
# 2398                  7.0   95845.0         UK       Asian       0
# ...

# %%
plt.hist(people_level_0["salary_level"])
plt.show()

# %%
mask_level_1 = salary_data["Education Level"] == 1
people_level_1 = salary_data[mask_level_1]
plt.hist(people_level_1["salary_level"])
plt.show()

# %%
mask_level_2 = salary_data["Education Level"] == 2
people_level_2 = salary_data[mask_level_2]
plt.hist(people_level_2["salary_level"])
plt.show()

# %% [markdown]
# ### Let's do a p-value test for education level 1

# %%
total_people = len(people_level_1)
low_salary_people = len(people_level_1[people_level_1["salary_level"] == "Low"])
high_salary_people = len(people_level_1[people_level_1["salary_level"] == "High"])
print("Total people in education level 1 is: ", total_people)
print("The number of low salary people in education level 1 is: ", low_salary_people)
print("The number of high salary people in education level 1 is: ", high_salary_people)
print("The percentage of high salary people in education level 1 is: ", high_salary_people / total_people)
# Out:
# Total people in education level 1 is:  3021
# The number of low salary people in education level 1 is:  2090
# The number of high salary people in education level 1 is:  931
# The percentage of high salary people in education level 1 is:  0.3081761006289308

# %% [markdown]
# ### Analogy:
#
# Total number of people <-> Times of tossing coins
#
# High Salary <-> Head of the coin
#
# Low Salary <-> Tail of the coin

# %%
import sys
sys.path.insert(0,"/Users/yuema/MyCode/summer_data_science_hw")
import lecture1

# %%
from lecture1.find_p_value import plot_binomial_with_pvalue

# %%
guess = high_salary_people / total_people

# %%
plot_binomial_with_pvalue(n=len(people_level_1["salary_level"]),
                          p=guess, 
                          observed_heads=len(people_level_1[people_level_1["salary_level"] == "High"]))

# %%
plot_binomial_with_pvalue(n=len(people_level_1["salary_level"]),
                          p=guess - 0.01,  
                          observed_heads=len(people_level_1[people_level_1["salary_level"] == "High"]))

# %%
plot_binomial_with_pvalue(n=len(people_level_1["salary_level"]),
                          p=guess + 0.01,  
                          observed_heads=len(people_level_1[people_level_1["salary_level"] == "High"]))
