# %% [markdown]
# # Exploratory data analysis
#
# First, load the dataset

# %%
import pandas as pd

# %%
salary_data = pd.read_csv("../lecture1/Salary.csv")
salary_data
# Out:
#        Age  Gender  Education Level              Job Title  \
# 0     32.0    Male                1      Software Engineer
# 1     28.0  Female                2           Data Analyst
# 2     45.0    Male                3                Manager
# 3     36.0  Female                1        Sales Associate
# 4     52.0    Male                2               Director
# ...    ...     ...              ...                    ...
# 6679  49.0  Female                3  Director of Marketing
# 6680  32.0    Male                0        Sales Associate
# 6681  30.0  Female                1      Financial Manager
# 6682  46.0    Male                2      Marketing Manager
# 6683  26.0  Female                0        Sales Executive
#
#       Years of Experience    Salary    Country        Race  Senior
# 0                     5.0   90000.0         UK       White       0
# 1                     3.0   65000.0        USA    Hispanic       0
# ...

# %% [markdown]
# ## 1. What is the median salary
# ### 1.1 Median salary of the entire dataset

# %%
average = salary_data["Salary"].mean()
median = salary_data["Salary"].median()
print("Average salary: ", average)
print("Median salary: ", median)
# Out:
# Average salary:  115307.17519449431
# Median salary:  115000.0

# %% [markdown]
# ### 1.2 Median salary of each education level

# %%
median_salary_per_education_level = {"Education Level": [], "Median Salary": []}
levels = salary_data["Education Level"].unique()
for level in levels:
    median_salary_per_education_level["Education Level"].append(level)
    median_salary_per_education_level["Median Salary"].append(salary_data[salary_data["Education Level"] == level]["Salary"].median())

pd.DataFrame(median_salary_per_education_level).sort_values(by="Median Salary")
# Out:
#    Education Level  Median Salary
# 3                0        30000.0
# 0                1        80000.0
# 1                2       130000.0
# 2                3       170000.0

# %% [markdown]
# ### 1.3 Median salary of each job title

# %%
# Follow the examples above, construct a table with the median salary of each job title and education level.

# %% [markdown]
# ## 2. Explore distributions

# %%
# distribution of salary
salary_data["Salary"].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# distribution of age

# %%
# distribution of years of experience

# %%
# distribution of education level
salary_data["Education Level"].value_counts().sort_index().plot.bar()
# Out:
# <Axes: xlabel='Education Level'>

# %%
# distribution of job title (top 10 only)
salary_data["Job Title"].value_counts().sort_values(ascending=False).head(10).plot.bar()
# Out:
# <Axes: xlabel='Job Title'>

# %%
# distribution of race

# %%
# distribution of country

# %% [markdown]
# ## 3. Explore relationships

# %%
# relationship between salary and age
salary_data.plot.scatter(x="Age", y="Salary")

# relationship between salary and age for Software Engineer in China only
salary_data[(salary_data["Job Title"] == "Software Engineer") & (salary_data["Country"] == "China")].plot.scatter(x="Age", y="Salary")
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
# relationship between salary and years of experience
